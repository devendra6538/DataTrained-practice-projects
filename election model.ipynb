# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt           ##importing necessary libaries

# %%
df=pd.read_csv('election_data.csv')    # dataset

# %%
df
# Out:
#        TimeElapsed             time        territoryName  totalMandates  \
# 0                0  10/6/2019 20:10  Território Nacional              0
# 1                0  10/6/2019 20:10  Território Nacional              0
# 2                0  10/6/2019 20:10  Território Nacional              0
# 3                0  10/6/2019 20:10  Território Nacional              0
# 4                0  10/6/2019 20:10  Território Nacional              0
# ...            ...              ...                  ...            ...
# 21638          265   10/7/2019 0:35                Viseu              8
# 21639          265   10/7/2019 0:35                Viseu              8
# 21640          265   10/7/2019 0:35                Viseu              8
# 21641          265   10/7/2019 0:35                Viseu              8
# 21642          265   10/7/2019 0:35                Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# ...

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
sns.heatmap(df.isnull())     #checking null values

# %%
corr=df.corr()
corr                       #co-relation between features
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# ...

# %%
plt.figure(figsize=(18,13))
sns.heatmap(corr,annot=True,fmt='.0%',cmap='cool')
plt.show()

# %%
plt.figure(figsize=(10,8))
df.drop('FinalMandates',axis=1).corrwith(df['FinalMandates']).plot(kind='bar',grid=True)
plt.show()

# %%
Observation:-
Here accept nullVotesPercentage and pre.nullVotesPercentage others are positively co-related with target variable

# %%
df['FinalMandates'].value_counts()
# Out:
# 0      17823
# 1       1134
# 2        695
# 3        641
# 4        378
# 5        270
# 8        108
# 12       108
# 7         54
# 6         54
# 77        54
# 20        54
# 19        54
# 9         54
# 106       54
# 17        54
# 15        54
# Name: FinalMandates, dtype: int64

# %%
fee = df['FinalMandates'].hist(bins=20)
mean_val=np.mean(df['FinalMandates'])
plt.axvline(mean_val,linewidth=4,color='red',label='mean ')
plt.xlabel('FinalMandates')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='territoryName',data=df,palette='rainbow')
plt.title('count for territoryName')
plt.xlabel('territoryName')
plt.xticks(rotation='vertical')
plt.ylabel('count')
plt.show()

print(df['territoryName'].value_counts())
# Out:
# Leiria                 1134
# Porto                  1134
# Território Nacional    1134
# Braga                  1134
# Madeira                1080
# Coimbra                1080
# Viana do Castelo       1080
# Setúbal                1080
# Lisboa                 1080
# Viseu                  1080
# Aveiro                 1080
# Santarém               1026
# Faro                   1026
# Guarda                 1026
# Évora                  1026
# Bragança                972
# Castelo Branco          972
# Beja                    918
# Portalegre              918
# Vila Real               864
# Açores                  799
# Name: territoryName, dtype: int64

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='totalMandates',data=df,palette='rainbow')
plt.title('count of totalMandates')
plt.xlabel('Party')
plt.xticks(rotation='vertical')
plt.ylabel('count')
plt.show()

print(df['totalMandates'].value_counts())
# Out:
# 0      5055
# 3      2949
# 2      1755
# 9      1726
# 6      1419
#        ...
# 22       21
# 197      21
# 149      21
# 37       21
# 17       20
# Name: totalMandates, Length: 62, dtype: int64

# %%
df.skew()
# Out:
# TimeElapsed                 -0.005496
# totalMandates                5.150031
# availableMandates            5.131572
# numParishes                  3.920433
# numParishesApproved          4.238343
# blankVotes                   4.521940
# blankVotesPercentage         0.069627
# nullVotes                    4.520945
# nullVotesPercentage          0.855419
# votersPercentage            -1.158029
# subscribedVoters             4.568797
# totalVoters                  4.541364
# pre.blankVotes               4.551489
# pre.blankVotesPercentage     0.021609
# pre.nullVotes                4.563235
# pre.nullVotesPercentage      1.231109
# pre.votersPercentage        -0.779289
# pre.subscribedVoters         4.565085
# pre.totalVoters              4.548030
# Mandates                    16.576658
# Percentage                   2.542328
# validVotesPercentage         2.543122
# Votes                       13.940573
# Hondt                       11.489315
# FinalMandates               12.402865
# ...

# %%
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<-0.55:
            df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# TimeElapsed                -0.005496
# totalMandates               2.726698
# availableMandates           2.335080
# numParishes                 3.382269
# numParishesApproved         3.221391
# blankVotes                  2.865581
# blankVotesPercentage        0.069627
# nullVotes                   3.023638
# nullVotesPercentage         0.622367
# votersPercentage           -1.415188
# subscribedVoters            3.046594
# totalVoters                 2.983802
# pre.blankVotes              2.921578
# pre.blankVotesPercentage    0.021609
# pre.nullVotes               3.079461
# pre.nullVotesPercentage     0.890172
# pre.votersPercentage       -0.903142
# pre.subscribedVoters        3.063726
# pre.totalVoters             3.014573
# Mandates                    6.471708
# Percentage                  1.883739
# validVotesPercentage        1.884549
# Votes                       5.588196
# Hondt                       4.650002
# FinalMandates               5.089621
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()      # converting object to integer

# %%
df
# Out:
#        TimeElapsed             time        territoryName  totalMandates  \
# 0                0  10/6/2019 20:10  Território Nacional       0.000000
# 1                0  10/6/2019 20:10  Território Nacional       0.000000
# 2                0  10/6/2019 20:10  Território Nacional       0.000000
# 3                0  10/6/2019 20:10  Território Nacional       0.000000
# 4                0  10/6/2019 20:10  Território Nacional       0.000000
# ...            ...              ...                  ...            ...
# 21638          265   10/7/2019 0:35                Viseu       2.828427
# 21639          265   10/7/2019 0:35                Viseu       2.828427
# 21640          265   10/7/2019 0:35                Viseu       2.828427
# 21641          265   10/7/2019 0:35                Viseu       2.828427
# 21642          265   10/7/2019 0:35                Viseu       2.828427
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# ...

# %%
df['territoryName'] = le.fit_transform(df['territoryName'])

# %%
df['Party']=le.fit_transform(df['Party'])

# %%
df.head(5)
# Out:
#    TimeElapsed                time  territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:00             16            0.0
# 1            0 2019-10-06 20:10:00             16            0.0
# 2            0 2019-10-06 20:10:00             16            0.0
# 3            0 2019-10-06 20:10:00             16            0.0
# 4            0 2019-10-06 20:10:00             16            0.0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0          15.033296    55.605755            32.878564   98.244593
# 1          15.033296    55.605755            32.878564   98.244593
# 2          15.033296    55.605755            32.878564   98.244593
# 3          15.033296    55.605755            32.878564   98.244593
# 4          15.033296    55.605755            32.878564   98.244593
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5  94.201911  ...              3.748236
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  int32
#  3   totalMandates             21643 non-null  float64
#  4   availableMandates         21643 non-null  float64
#  5   numParishes               21643 non-null  float64
#  6   numParishesApproved       21643 non-null  float64
#  7   blankVotes                21643 non-null  float64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  float64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  float64
# ...

# %%
df['time']=pd.to_datetime(df['time'])

# %%
df['time'].dt.month
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 21638    10
# 21639    10
# 21640    10
# 21641    10
# 21642    10
# Name: time, Length: 21643, dtype: int64

# %%
df['time'].dt.day
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 21638    7
# 21639    7
# 21640    7
# 21641    7
# 21642    7
# Name: time, Length: 21643, dtype: int64

# %%
df['day'] = df['time'].dt.day

# %%
df = df.drop('time',axis = 1)

# %%
df['availableMandates'].plot.box()                      #cheacking outliers with box plot

# %%
df['validVotesPercentage'].plot.box()

# %%
df['Votes'].plot.box()

# %%
df['pre.subscribedVoters'].plot.box()

# %%
df['Percentage'].plot.box()

# %%
df['pre.votersPercentage'].plot.box()

# %%
df['availableMandates'].plot.box()

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))                         #treaating outlier
z
# Out:
# array([[1.71470808, 0.98296816, 0.92619344, ..., 9.35584053, 9.93528112,
#         0.41837381],
#        [1.71470808, 0.98296816, 0.92619344, ..., 8.65882148, 8.41572456,
#         0.41837381],
#        [1.71470808, 0.98296816, 0.92619344, ..., 3.64688999, 4.00288025,
#         0.41837381],
#        ...,
#        [1.69806785, 1.48421407, 0.20843944, ..., 0.3626552 , 0.35283926,
#         2.39020696],
#        [1.69806785, 1.48421407, 0.20843944, ..., 0.3626552 , 0.35283926,
#         2.39020696],
#        [1.69806785, 1.48421407, 0.20843944, ..., 0.3626552 , 0.35283926,
#         2.39020696]])

# %%
threshold = 3

# %%
print(np.where(z>3))
# Out:
# (array([    0,     0,     0, ..., 21528, 21567, 21567], dtype=int64), array([ 3,  4, 25, ..., 26, 21, 24], dtype=int64))

# %%
new_df = df[(z<3).all(axis=1)]

# %%
print(df.shape,'\t\t',new_df.shape)
# Out:
# (21643, 28) 		 (18876, 28)

# %%
df = new_df
df
# Out:
#        TimeElapsed  territoryName  totalMandates  availableMandates  \
# 21               0              0       0.000000                4.0
# 22               0              0       0.000000                4.0
# 23               0              0       0.000000                4.0
# 24               0              0       0.000000                4.0
# 25               0              0       0.000000                4.0
# ...            ...            ...            ...                ...
# 21638          265             19       2.828427                0.0
# 21639          265             19       2.828427                0.0
# 21640          265             19       2.828427                0.0
# 21641          265             19       2.828427                0.0
# 21642          265             19       2.828427                0.0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 21       12.124356             3.464102   13.638182                  2.92
# ...

# %%
x= df.drop(columns=['FinalMandates'],axis=1)
x.head()
# Out:
#     TimeElapsed  territoryName  totalMandates  availableMandates  numParishes  \
# 21            0              0            0.0                4.0    12.124356
# 22            0              0            0.0                4.0    12.124356
# 23            0              0            0.0                4.0    12.124356
# 24            0              0            0.0                4.0    12.124356
# 25            0              0            0.0                4.0    12.124356
#
#     numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 21             3.464102   13.638182                  2.92  10.049876
# 22             3.464102   13.638182                  2.92  10.049876
# 23             3.464102   13.638182                  2.92  10.049876
# 24             3.464102   13.638182                  2.92  10.049876
# 25             3.464102   13.638182                  2.92  10.049876
#
#     nullVotesPercentage  ...  pre.votersPercentage  pre.subscribedVoters  \
# ...

# %%
y= df['FinalMandates']
y.head()
# Out:
# 21    2.449490
# 22    2.645751
# 23    1.414214
# 24    1.000000
# 25    0.000000
# Name: FinalMandates, dtype: float64

# %%
print('x shape =',x.shape,'\t\t','y shape =',y.shape)    #checking shape of x and y
# Out:
# x shape = (18876, 27) 		 y shape = (18876,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()  #scaling

# %%
x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression     #building model
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size =.20,random_state=42)

# %%
print('x_train.shape =',x_train.shape,'\t\t','x_test.shape =',x_test.shape)
print('y_train.shape =',y_train.shape,'\t\t','y_test.shape =',y_test.shape)
# Out:
# x_train.shape = (15100, 27) 		 x_test.shape = (3776, 27)
# y_train.shape = (15100,) 		 y_test.shape = (3776,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9759253843163463

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([ 0.01724099, -0.01226532,  0.08439261, ...,  0.01005522,
#         0.00571449, -0.00181579])

# %%
print('error')

print("mean absolute error =",mean_absolute_error(y_test,pred))
print("mean squared error =",mean_squared_error(y_test,pred))

print("root mean squared error =",np.sqrt(mean_squared_error(y_test,pred)))

print("r2_score =",r2_score(y_test,pred))
# Out:
# error
# mean absolute error = 0.022239341936412627
# mean squared error = 0.005290868657929126
# root mean squared error = 0.0727383575421464
# r2_score = 0.9837880336221939

# %%
Here we are getting r2 score 98% ie are model is working great.

# %%
import joblib

# %%
joblib.dump(lr,"election")       #saving model
# Out:
# ['election']
