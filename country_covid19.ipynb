# %%
import numpy as np
import pandas as pd                        #importing necessary libaries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('covid_onemonth.csv') #datset

# %%
df
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-18                 Russia   145927292    1831892.0      36793.0
# 2     2020-04-18                  Spain    46752703     930230.0     194416.0
# 3     2020-04-18                 Brazil   212380932      62985.0      36722.0
# 4     2020-04-18                     UK    67844241     460437.0     114217.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-18              St. Barth        9874          NaN          6.0
# 6599  2020-05-18         Western Sahara      595462          NaN          6.0
# 6600  2020-05-18               Anguilla       14987          NaN          3.0
# 6601  2020-05-18                Lesotho     2140235          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Country', 'Population', 'Total Tests', 'Total Cases',
#        'Total Deaths', 'Total Recovered', 'Serious or Critical',
#        'Active Cases'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6603 entries, 0 to 6602
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6603 non-null   object
#  1   Country              6603 non-null   object
#  2   Population           6603 non-null   int64
#  3   Total Tests          5505 non-null   float64
#  4   Total Cases          6554 non-null   float64
#  5   Total Deaths         5367 non-null   float64
#  6   Total Recovered      6318 non-null   float64
#  7   Serious or Critical  4117 non-null   float64
#  8   Active Cases         6544 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 464.4+ KB

# %%
data=pd.read_csv('covid_age.csv')

# %%
data
# Out:
#                    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0                      USA                    0.189                     0.657
# 1                   Russia                    0.176                     0.682
# 2                    Spain                    0.147                     0.659
# 3                   Brazil                    0.217                     0.697
# 4                       UK                    0.177                     0.638
# ..                     ...                      ...                       ...
# 208              St. Barth                      NaN                       NaN
# 209         Western Sahara                      NaN                       NaN
# 210               Anguilla                      NaN                       NaN
# 211                Lesotho                    0.354                     0.601
# 212  Saint Pierre Miquelon                      NaN                       NaN
#
#      Fraction age 65+ years
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   213 non-null    object
#  1   Fraction age 0-14 years   176 non-null    float64
#  2   Fraction age 15-64 years  176 non-null    float64
#  3   Fraction age 65+ years    176 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 6.8+ KB

# %%
dataset=pd.merge(df,data,on='Country')   #merging both the dataset

# %%
dataset
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-19                    USA   330774664    3861549.0     763832.0
# 2     2020-04-20                    USA   330774664    4026360.0     792759.0
# 3     2020-04-21                    USA   330774664    4187392.0     818744.0
# 4     2020-04-22                    USA   330774664    4325342.0     848717.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-14  Saint Pierre Miquelon        5797          NaN          1.0
# 6599  2020-05-15  Saint Pierre Miquelon        5797          NaN          1.0
# 6600  2020-05-16  Saint Pierre Miquelon        5797          NaN          1.0
# 6601  2020-05-17  Saint Pierre Miquelon        5797          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
df.head(20)
# Out:
#           Date       Country  Population  Total Tests  Total Cases  \
# 0   2020-04-18           USA   330774664    3722145.0     738792.0
# 1   2020-04-18        Russia   145927292    1831892.0      36793.0
# 2   2020-04-18         Spain    46752703     930230.0     194416.0
# 3   2020-04-18        Brazil   212380932      62985.0      36722.0
# 4   2020-04-18            UK    67844241     460437.0     114217.0
# 5   2020-04-18         Italy    60471924    1305833.0     175925.0
# 6   2020-04-18        France    65256826     463662.0     151793.0
# 7   2020-04-18       Germany    83752855    1728357.0     143724.0
# 8   2020-04-18        Turkey    84230075     598933.0      82329.0
# 9   2020-04-18          Iran    83862642     330137.0      80868.0
# 10  2020-04-18         India  1378381772     335123.0      16365.0
# 11  2020-04-18          Peru    32915899     135895.0      14420.0
# 12  2020-04-18         China  1439323776          NaN      82719.0
# ...

# %%
df=dataset

# %%
df
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-19                    USA   330774664    3861549.0     763832.0
# 2     2020-04-20                    USA   330774664    4026360.0     792759.0
# 3     2020-04-21                    USA   330774664    4187392.0     818744.0
# 4     2020-04-22                    USA   330774664    4325342.0     848717.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-14  Saint Pierre Miquelon        5797          NaN          1.0
# 6599  2020-05-15  Saint Pierre Miquelon        5797          NaN          1.0
# 6600  2020-05-16  Saint Pierre Miquelon        5797          NaN          1.0
# 6601  2020-05-17  Saint Pierre Miquelon        5797          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                           0
# Country                        0
# Population                     0
# Total Tests                 1098
# Total Cases                   49
# Total Deaths                1236
# Total Recovered              285
# Serious or Critical         2486
# Active Cases                  59
# Fraction age 0-14 years     1147
# Fraction age 15-64 years    1147
# Fraction age 65+ years      1147
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)      #checking null values

# %%
column=['Total Tests','Total Cases','Total Deaths','Total Recovered','Serious or Critical','Active Cases','Fraction age 0-14 years','Fraction age 15-64 years','Fraction age 65+ years']

# %%
for col in column:
    df[col].fillna(df[col].mean(),inplace=True)      #treating null values

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df
# Out:
#             Date                Country  Population   Total Tests  \
# 0     2020-04-18                    USA   330774664  3.722145e+06
# 1     2020-04-19                    USA   330774664  3.861549e+06
# 2     2020-04-20                    USA   330774664  4.026360e+06
# 3     2020-04-21                    USA   330774664  4.187392e+06
# 4     2020-04-22                    USA   330774664  4.325342e+06
# ...          ...                    ...         ...           ...
# 6598  2020-05-14  Saint Pierre Miquelon        5797  2.167252e+05
# 6599  2020-05-15  Saint Pierre Miquelon        5797  2.167252e+05
# 6600  2020-05-16  Saint Pierre Miquelon        5797  2.167252e+05
# 6601  2020-05-17  Saint Pierre Miquelon        5797  2.167252e+05
# 6602  2020-05-18  Saint Pierre Miquelon        5797  2.167252e+05
#
#       Total Cases  Total Deaths  Total Recovered  Serious or Critical  \
# 0        738792.0  39014.000000          68269.0          13551.00000
# ...

# %%
df['Date'].unique()
# Out:
# array(['2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21',
#        '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25',
#        '2020-04-26', '2020-04-27', '2020-04-28', '2020-04-29',
#        '2020-04-30', '2020-05-01', '2020-05-02', '2020-05-03',
#        '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07',
#        '2020-05-08', '2020-05-09', '2020-05-10', '2020-05-11',
#        '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15',
#        '2020-05-16', '2020-05-17', '2020-05-18'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['USA', 'Russia', 'Spain', 'Brazil', 'UK', 'Italy', 'France',
#        'Germany', 'Turkey', 'Iran', 'India', 'Peru', 'China', 'Canada',
#        'Saudi Arabia', 'Belgium', 'Mexico', 'Chile', 'Netherlands',
#        'Pakistan', 'Qatar', 'Ecuador', 'Switzerland', 'Belarus', 'Sweden',
#        'Portugal', 'Singapore', 'Ireland', 'UAE', 'Bangladesh', 'Poland',
#        'Ukraine', 'Indonesia', 'Romania', 'Israel', 'South Africa',
#        'Japan', 'Colombia', 'Austria', 'Kuwait', 'Egypt',
#        'Dominican Republic', 'Philippines', 'S. Korea', 'Denmark',
#        'Serbia', 'Panama', 'Czechia', 'Argentina', 'Norway', 'Algeria',
#        'Bahrain', 'Afghanistan', 'Australia', 'Morocco', 'Malaysia',
#        'Kazakhstan', 'Finland', 'Nigeria', 'Moldova', 'Ghana', 'Oman',
#        'Armenia', 'Bolivia', 'Luxembourg', 'Iraq', 'Hungary', 'Cameroon',
#        'Azerbaijan', 'Thailand', 'Greece', 'Guinea', 'Uzbekistan',
#        'Honduras', 'Sudan', 'Senegal', 'Bosnia and Herzegovina',
# ...

# %%
df.describe()
# Out:
#          Population   Total Tests   Total Cases  Total Deaths  \
# count  6.603000e+03  6.603000e+03  6.603000e+03   6603.000000
# mean   3.637913e+07  2.167252e+05  1.692968e+04   1416.252096
# std    1.411537e+08  6.934856e+05  8.828521e+04   5990.992214
# min    8.010000e+02  1.000000e+01  1.000000e+00      0.000000
# 25%    8.672680e+05  4.733000e+03  8.000000e+01      8.000000
# 50%    6.859926e+06  5.419500e+04  6.320000e+02     55.000000
# 75%    2.546422e+07  2.167252e+05  5.222500e+03   1416.252096
# max    1.439324e+09  1.230074e+07  1.550294e+06  91981.000000
#
#        Total Recovered  Serious or Critical  Active Cases  \
# count      6603.000000          6603.000000  6.603000e+03
# mean       5855.424185           386.748360  9.964142e+03
# std       22955.519135          1309.473245  6.511732e+04
# min           1.000000             1.000000  0.000000e+00
# 25%          29.000000             7.000000  2.700000e+01
# ...

# %%
corr=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,fmt='.0%',cmap='cool')       #co-relation
plt.show()

# %%
plt.figure(figsize=(10,8))
df.drop('Total Recovered',axis=1).corrwith(df['Total Recovered']).plot(kind='bar',grid=True)  #co-relation with target variable
plt.xticks(rotation=20)
plt.title('correlation with target variable')
# Out:
# Text(0.5, 1.0, 'correlation with target variable')

# %% [raw]
# observation:-
#     only Fraction age 0-14 years is negativly co-orelated with target variable,others are positivly co-orelated

# %%
df.head(2)
# Out:
#          Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0  2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1  2020-04-19     USA   330774664    3861549.0     763832.0       40553.0
#
#    Total Recovered  Serious or Critical  Active Cases  \
# 0          68269.0              13551.0      631509.0
# 1          71003.0              13566.0      652276.0
#
#    Fraction age 0-14 years  Fraction age 15-64 years  Fraction age 65+ years
# 0                    0.189                     0.657                   0.154
# 1                    0.189                     0.657                   0.154

# %%
death=df['Total Deaths'].hist()
mean_val=np.mean(df['Total Deaths'])
plt.axvline(mean_val,linewidth=4,color='red',label='Total Death mean')
plt.xlabel('Total Deaths')
plt.legend
plt.show()
print('Total Deaths mean =',df['Total Deaths'].mean())
# Out:
# Total Deaths mean = 1416.252096143086

# %%
tests=df['Total Tests'].hist()
mean_val=np.mean(df['Total Deaths'])
plt.axvline(mean_val,linewidth=4,color='red',label='Total Tests mean')
plt.xlabel('Total Tests')
plt.legend
plt.show()
print('Total Tests mean =',df['Total Tests'].mean())
# Out:
# Total Tests mean = 216725.16130788767

# %%
cases=df['Total Cases'].hist()
mean_val=np.mean(df['Total Cases'])
plt.axvline(mean_val,linewidth=4,color='red',label='Total Cases mean')
plt.xlabel('Total Cases')
plt.legend
plt.show()
print('Total Cases mean =',df['Total Cases'].mean())
# Out:
# Total Cases mean = 16929.67821177906

# %%
Recovered=df['Total Recovered'].hist()
mean_val=np.mean(df['Total Recovered'])
plt.axvline(mean_val,linewidth=4,color='red',label='Total Recovered mean')
plt.xlabel('Total Recovered')
plt.legend
plt.show()
print('Total Recovered mean =',df['Total Recovered'].mean())
# Out:
# Total Recovered mean = 5855.424184868553

# %%
active=df['Active Cases'].hist()
mean_val=np.mean(df['Active Cases'])
plt.axvline(mean_val,linewidth=4,color='red',label='Active Cases mean')
plt.xlabel('Active Cases')
plt.legend
plt.show()
print('Active Cases mean =',df['Active Cases'].mean())
# Out:
# Active Cases mean = 9964.14211491443

# %%
print('Total Tests mean =',df['Total Tests'].mean())
print('Total Cases mean =',df['Total Cases'].mean())
print('Total Deaths mean =',df['Total Deaths'].mean())
print('Total Recovered mean =',df['Total Recovered'].mean())
print('Active Cases mean =',df['Active Cases'].mean())
# Out:
# Total Tests mean = 216725.16130788767
# Total Cases mean = 16929.67821177906
# Total Deaths mean = 1416.252096143086
# Total Recovered mean = 5855.424184868553
# Active Cases mean = 9964.14211491443

# %%
sns.catplot(x='Date',y='Total Recovered',data=df,kind='bar',size=3,palette='muted',aspect=5)
plt.title('Recovery according to Date')
plt.xticks(rotation='vertical')
plt.ylabel=('count')
plt.show()
# Out:
# C:\Users\Dell Laptop\anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Date',y='Total Deaths',data=df,kind='bar',size=3,palette='muted',aspect=5)
plt.title('Total Deaths according to Date')
plt.xticks(rotation='vertical')
plt.ylabel=('count')
plt.show()

# %%
sns.catplot(x='Date',y='Total Tests',data=df,kind='bar',size=3,palette='muted',aspect=5)
plt.title('Total Tests according to Date')
plt.xticks(rotation='vertical')
plt.ylabel=('count')
plt.show()

# %%
sns.catplot(x='Date',y='Active Cases',data=df,kind='bar',size=3,palette='muted',aspect=5)
plt.title('Active Cases according to Date')
plt.xticks(rotation='vertical')
plt.ylabel=('count')
plt.show()

# %%
df.skew()    #cheaking skewness of data
# Out:
# Population                   8.743503
# Total Tests                  9.340104
# Total Cases                 12.079982
# Total Deaths                 8.951957
# Total Recovered              7.220713
# Serious or Critical          9.199670
# Active Cases                13.301517
# Fraction age 0-14 years      0.388389
# Fraction age 15-64 years    -0.133140
# Fraction age 65+ years       0.847017
# dtype: float64

# %%
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])     #treating skewness
        if df[col].skew()<-0.55:
            df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# Population                  4.004943
# Total Tests                 3.198289
# Total Cases                 4.759674
# Total Deaths                3.992740
# Total Recovered             3.647617
# Serious or Critical         3.573630
# Active Cases                6.034296
# Fraction age 0-14 years     0.388389
# Fraction age 15-64 years   -0.133140
# Fraction age 65+ years      0.385808
# dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6603 entries, 0 to 6602
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      6603 non-null   datetime64[ns]
#  1   Country                   6603 non-null   object
#  2   Population                6603 non-null   float64
#  3   Total Tests               6603 non-null   float64
#  4   Total Cases               6603 non-null   float64
#  5   Total Deaths              6603 non-null   float64
#  6   Total Recovered           6603 non-null   float64
#  7   Serious or Critical       6603 non-null   float64
#  8   Active Cases              6603 non-null   float64
#  9   Fraction age 0-14 years   6603 non-null   float64
#  10  Fraction age 15-64 years  6603 non-null   float64
#  11  Fraction age 65+ years    6603 non-null   float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 990.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder 

le = LabelEncoder()                         #converting object to interger

# %%
df
# Out:
#            Date                Country    Population  Total Tests  \
# 0    2020-04-18                    USA  18187.211551  1929.286137
# 1    2020-04-19                    USA  18187.211551  1965.082441
# 2    2020-04-20                    USA  18187.211551  2006.579179
# 3    2020-04-21                    USA  18187.211551  2046.311804
# 4    2020-04-22                    USA  18187.211551  2079.745658
# ...         ...                    ...           ...          ...
# 6598 2020-05-14  Saint Pierre Miquelon     76.138033   465.537497
# 6599 2020-05-15  Saint Pierre Miquelon     76.138033   465.537497
# 6600 2020-05-16  Saint Pierre Miquelon     76.138033   465.537497
# 6601 2020-05-17  Saint Pierre Miquelon     76.138033   465.537497
# 6602 2020-05-18  Saint Pierre Miquelon     76.138033   465.537497
#
#       Total Cases  Total Deaths  Total Recovered  Serious or Critical  \
# 0      859.530104    197.519619       261.283371           116.408763
# ...

# %%
df.Country = le.fit_transform(df.Country)

# %%
df
# Out:
#            Date  Country    Population  Total Tests  Total Cases  \
# 0    2020-04-18      201  18187.211551  1929.286137   859.530104
# 1    2020-04-19      201  18187.211551  1965.082441   873.974828
# 2    2020-04-20      201  18187.211551  2006.579179   890.370148
# 3    2020-04-21      201  18187.211551  2046.311804   904.844738
# 4    2020-04-22      201  18187.211551  2079.745658   921.258379
# ...         ...      ...           ...          ...          ...
# 6598 2020-05-14      165     76.138033   465.537497     1.000000
# 6599 2020-05-15      165     76.138033   465.537497     1.000000
# 6600 2020-05-16      165     76.138033   465.537497     1.000000
# 6601 2020-05-17      165     76.138033   465.537497     1.000000
# 6602 2020-05-18      165     76.138033   465.537497     1.000000
#
#       Total Deaths  Total Recovered  Serious or Critical  Active Cases  \
# 0       197.519619       261.283371           116.408763    794.675405
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6603 entries, 0 to 6602
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      6603 non-null   datetime64[ns]
#  1   Country                   6603 non-null   int32
#  2   Population                6603 non-null   float64
#  3   Total Tests               6603 non-null   float64
#  4   Total Cases               6603 non-null   float64
#  5   Total Deaths              6603 non-null   float64
#  6   Total Recovered           6603 non-null   float64
#  7   Serious or Critical       6603 non-null   float64
#  8   Active Cases              6603 non-null   float64
#  9   Fraction age 0-14 years   6603 non-null   float64
#  10  Fraction age 15-64 years  6603 non-null   float64
#  11  Fraction age 65+ years    6603 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int32(1)
# memory usage: 964.8 KB

# %%
df= df.drop(columns=['Date'],axis=1)

# %%
x= df.drop(columns=['Total Recovered'],axis=1)
x.head()
# Out:
#    Country    Population  Total Tests  Total Cases  Total Deaths  \
# 0      201  18187.211551  1929.286137   859.530104    197.519619
# 1      201  18187.211551  1965.082441   873.974828    201.377754
# 2      201  18187.211551  2006.579179   890.370148    206.189233
# 3      201  18187.211551  2046.311804   904.844738    212.880248
# 4      201  18187.211551  2079.745658   921.258379    218.309413
#
#    Serious or Critical  Active Cases  Fraction age 0-14 years  \
# 0           116.408763    794.675405                    0.189
# 1           116.473173    807.636057                    0.189
# 2           118.114351    823.320108                    0.189
# 3           118.389189    830.965102                    0.189
# 4           118.389189    846.763249                    0.189
#
#    Fraction age 15-64 years  Fraction age 65+ years
# 0                     0.657                0.392428
# 1                     0.657                0.392428
# ...

# %%
y= df['Total Recovered']
y.head()
# Out:
# 0    261.283371
# 1    266.463881
# 2    269.052040
# 3    287.963539
# 4    289.913780
# Name: Total Recovered, dtype: float64

# %%
df
# Out:
#       Country    Population  Total Tests  Total Cases  Total Deaths  \
# 0         201  18187.211551  1929.286137   859.530104    197.519619
# 1         201  18187.211551  1965.082441   873.974828    201.377754
# 2         201  18187.211551  2006.579179   890.370148    206.189233
# 3         201  18187.211551  2046.311804   904.844738    212.880248
# 4         201  18187.211551  2079.745658   921.258379    218.309413
# ...       ...           ...          ...          ...           ...
# 6598      165     76.138033   465.537497     1.000000     37.633125
# 6599      165     76.138033   465.537497     1.000000     37.633125
# 6600      165     76.138033   465.537497     1.000000     37.633125
# 6601      165     76.138033   465.537497     1.000000     37.633125
# 6602      165     76.138033   465.537497     1.000000     37.633125
#
#       Total Recovered  Serious or Critical  Active Cases  \
# 0          261.283371           116.408763    794.675405
# ...

# %%
print(x.shape,'\t\t',y.shape)
# Out:
# (6603, 10) 		 (6603,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x = sc.fit_transform(x)    #scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression     #building model

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size =.20,random_state=42)

# %%
print('x_train.shape =',x_train.shape,'\t\t','x_test.shape =',x_test.shape)
print('y_train.shape =',y_train.shape,'\t\t','y_test.shape =',y_test.shape)
# Out:
# x_train.shape = (5282, 10) 		 x_test.shape = (1321, 10)
# y_train.shape = (5282,) 		 y_test.shape = (1321,)

# %%
df
# Out:
#       Country    Population  Total Tests  Total Cases  Total Deaths  \
# 0         201  18187.211551  1929.286137   859.530104    197.519619
# 1         201  18187.211551  1965.082441   873.974828    201.377754
# 2         201  18187.211551  2006.579179   890.370148    206.189233
# 3         201  18187.211551  2046.311804   904.844738    212.880248
# 4         201  18187.211551  2079.745658   921.258379    218.309413
# ...       ...           ...          ...          ...           ...
# 6598      165     76.138033   465.537497     1.000000     37.633125
# 6599      165     76.138033   465.537497     1.000000     37.633125
# 6600      165     76.138033   465.537497     1.000000     37.633125
# 6601      165     76.138033   465.537497     1.000000     37.633125
# 6602      165     76.138033   465.537497     1.000000     37.633125
#
#       Total Recovered  Serious or Critical  Active Cases  \
# 0          261.283371           116.408763    794.675405
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6603 entries, 0 to 6602
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   6603 non-null   int32
#  1   Population                6603 non-null   float64
#  2   Total Tests               6603 non-null   float64
#  3   Total Cases               6603 non-null   float64
#  4   Total Deaths              6603 non-null   float64
#  5   Total Recovered           6603 non-null   float64
#  6   Serious or Critical       6603 non-null   float64
#  7   Active Cases              6603 non-null   float64
#  8   Fraction age 0-14 years   6603 non-null   float64
#  9   Fraction age 15-64 years  6603 non-null   float64
#  10  Fraction age 65+ years    6603 non-null   float64
# dtypes: float64(10), int32(1)
# memory usage: 913.2 KB

# %%
df
# Out:
#       Country    Population  Total Tests  Total Cases  Total Deaths  \
# 0         201  18187.211551  1929.286137   859.530104    197.519619
# 1         201  18187.211551  1965.082441   873.974828    201.377754
# 2         201  18187.211551  2006.579179   890.370148    206.189233
# 3         201  18187.211551  2046.311804   904.844738    212.880248
# 4         201  18187.211551  2079.745658   921.258379    218.309413
# ...       ...           ...          ...          ...           ...
# 6598      165     76.138033   465.537497     1.000000     37.633125
# 6599      165     76.138033   465.537497     1.000000     37.633125
# 6600      165     76.138033   465.537497     1.000000     37.633125
# 6601      165     76.138033   465.537497     1.000000     37.633125
# 6602      165     76.138033   465.537497     1.000000     37.633125
#
#       Total Recovered  Serious or Critical  Active Cases  \
# 0          261.283371           116.408763    794.675405
# ...

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.911175638075161

# %% [raw]
# Getting accuracy of 91% with LinearRegression

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([ 63.54444336,  14.5247987 , 359.48225468, ...,  26.09501602,
#         40.90897367,  45.31201306])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print('error')

print("mean absolute error =",mean_absolute_error(y_test,pred))
print("mean squared error =",mean_squared_error(y_test,pred))

print("root mean squared error =",np.sqrt(mean_squared_error(y_test,pred)))

print("r2_score =",r2_score(y_test,pred))
# Out:
# error
# mean absolute error = 8.599017412215067
# mean squared error = 253.27546193183312
# root mean squared error = 15.914630436545899
# r2_score = 0.9490708695636008

# %% [raw]
# obsevation:-
#     Here we are getting r2 score 94% ie are model is working great.

# %%
import joblib

# %%
joblib.dump(lr,"country_covid19")      #saving model
# Out:
# ['country_covid19']
