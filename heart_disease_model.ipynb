# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Heart_Disease.csv')

# %%
df
# Out:
#      Age  Sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     63    1   4      140  260   0        1     112     1       3     2  ?
# 1     44    1   4      130  209   0        1     127     0       0     ?  ?
# 2     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4     66    1   3      110  213   1        2      99     1     1.3     2  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 195   54    0   4      127  333   1        1     154     0       0     ?  ?
# 196   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 197   55    1   4      122  223   1        1     100     0       0     ?  ?
# 198   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 199   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    2
# 1      ?    0
# ...

# %%
There are 14 columns which are:-
    
    Age 
    Sex
    cp = Cheastpain
    trestbps = resting Blood Pressure
    chol = Cholestrol
    fbs = Fasting Blood Sugar
    resrecg = resting electrocardiographic
    thalach = Max heart rate achieved
    exang = Exercise induced angina 
    oldpeak = ST depression induced by exercise relative to rest
    slope = Peak exercise ST segment
    ca = Number of major vessels 
    thal = displays the thalassemia
    num = Diagnosis of heart disease

# %%
df.isnull().sum()
# Out:
# Age         0
# Sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
# Making a list of missing value types
missing_values = ["?"]
df = pd.read_csv("Heart_Disease.csv", na_values = missing_values)

# %%
df
# Out:
#      Age  Sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   4     140.0  260.0  0.0        1    112.0    1.0      3.0
# 1     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 2     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 3     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 4     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 195   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 196   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 197   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 198   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 199   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 0      2.0 NaN   NaN    2
# ...

# %%
df.isnull().sum()
# Out:
# Age           0
# Sex           0
# cp            0
# trestbps     56
# chol          7
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          198
# thal        166
# num           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       200 non-null    int64
#  1   Sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trestbps  144 non-null    float64
#  4   chol      193 non-null    float64
#  5   fbs       193 non-null    float64
#  6   restecg   200 non-null    int64
#  7   thalach   147 non-null    float64
#  8   exang     147 non-null    float64
#  9   oldpeak   144 non-null    float64
#  10  slope     98 non-null     float64
#  11  ca        2 non-null      float64
#  12  thal      34 non-null     float64
#  13  num       200 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 22.0 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#               Age         Sex          cp    trestbps        chol         fbs  \
# count  200.000000  200.000000  200.000000  144.000000  193.000000  193.000000
# mean    59.350000    0.970000    3.505000  133.763889  178.746114    0.352332
# std      7.811697    0.171015    0.795701   21.537733  114.035232    0.478939
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  216.000000    0.000000
# 75%     64.000000    1.000000    4.000000  147.000000  258.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak      slope   ca  \
# count  200.000000  147.000000  147.000000  144.000000  98.000000  2.0
# mean     0.735000  122.795918    0.646259    1.320833   2.132653  0.0
# ...

# %%
df
# Out:
#      Age  Sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   4     140.0  260.0  0.0        1    112.0    1.0      3.0
# 1     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 2     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 3     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 4     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 195   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 196   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 197   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 198   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 199   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 0      2.0 NaN   NaN    2
# ...

# %%
# Replace using mean 
mean = df['trestbps'].mean()
df['trestbps'].fillna(mean, inplace=True)

# %%
df['trestbps']
# Out:
# 0      140.000000
# 1      130.000000
# 2      132.000000
# 3      142.000000
# 4      110.000000
#           ...
# 195    127.000000
# 196    133.763889
# 197    122.000000
# 198    133.763889
# 199    120.000000
# Name: trestbps, Length: 200, dtype: float64

# %%
mean = df['thalach'].mean()
df['thalach'].fillna(mean, inplace=True)

# %%
df['thalach']
# Out:
# 0      112.000000
# 1      127.000000
# 2      140.000000
# 3      149.000000
# 4       99.000000
#           ...
# 195    154.000000
# 196    122.795918
# 197    100.000000
# 198    122.795918
# 199     93.000000
# Name: thalach, Length: 200, dtype: float64

# %%
df.exang.value_counts()
# Out:
# 1.0    95
# 0.0    52
# Name: exang, dtype: int64

# %%
df['exang'].median()
# Out:
# 1.0

# %%
# Replace using median 
median = df['exang'].median()
df['exang'].fillna(median, inplace=True)

# %%
df['oldpeak'].value_counts()
# Out:
#  0.0    40
#  2.0    25
#  1.5    21
#  1.0    18
#  3.0    13
#  2.5     9
#  0.5     7
#  4.0     4
#  1.3     2
#  1.7     1
#  0.8     1
#  1.6     1
#  3.5     1
# -0.5     1
# Name: oldpeak, dtype: int64

# %%
df['oldpeak'].isnull().sum()
# Out:
# 56

# %%
df['oldpeak'].mean()
# Out:
# 1.3208333333333333

# %%
mean = df['oldpeak'].mean()
df['oldpeak'].fillna(mean, inplace=True)

# %%
df['slope'].value_counts()
# Out:
# 2.0    53
# 3.0    29
# 1.0    16
# Name: slope, dtype: int64

# %%
df['slope'].mean()
# Out:
# 2.13265306122449

# %%
mean = df['slope'].mean()
df['slope'].fillna(mean, inplace=True)

# %%
df['ca'].value_counts()
# Out:
# 0.0    2
# Name: ca, dtype: int64

# %%
df['ca'].mean()
# Out:
# 0.0

# %%
mean = df['ca'].mean()
df['ca'].fillna(mean, inplace=True)

# %%
df['thal'].value_counts()
# Out:
# 6.294118    166
# 7.000000     22
# 6.000000      8
# 3.000000      4
# Name: thal, dtype: int64

# %%
df['thal'].mean()
# Out:
# 6.294117647058805

# %%
mean = df['thal'].mean()
df['thal'].fillna(mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# Age         0
# Sex         0
# cp          0
# trestbps    0
# chol        7
# fbs         7
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df['chol'].mean()
# Out:
# 178.7461139896373

# %%
mean = df['chol'].mean()
df['chol'].fillna(mean, inplace=True)

# %%
df['fbs'].value_counts()
# Out:
# 0.0    125
# 1.0     68
# Name: fbs, dtype: int64

# %%
df['fbs'].mean()
# Out:
# 0.35233160621761656

# %%
mean = df['fbs'].mean()
df['fbs'].fillna(mean, inplace=True)

# %%
sns.heatmap(df.isnull())

# %% [raw]
# all null or NaN values replaced with mean or median

# %%
df
# Out:
#      Age  Sex  cp    trestbps   chol  fbs  restecg     thalach  exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000    1.0
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000    0.0
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000    1.0
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000    1.0
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000    1.0
# ..   ...  ...  ..         ...    ...  ...      ...         ...    ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000    0.0
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918    1.0
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000    0.0
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918    1.0
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000    1.0
#
#       oldpeak     slope   ca      thal  num
# 0    3.000000  2.000000  0.0  6.294118    2
# ...

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values,cmap='Reds')
corr  #correlation between columns
# Out:
#                Age       Sex        cp  trestbps      chol       fbs  \
# Age       1.000000  0.034230 -0.038280  0.181584  0.066972  0.124753
# Sex       0.034230  1.000000  0.038036  0.012585 -0.096150 -0.055341
# cp       -0.038280  0.038036  1.000000  0.074638  0.065818 -0.047368
# trestbps  0.181584  0.012585  0.074638  1.000000  0.150192  0.184605
# chol      0.066972 -0.096150  0.065818  0.150192  1.000000  0.151512
# fbs       0.124753 -0.055341 -0.047368  0.184605  0.151512  1.000000
# restecg   0.002400  0.060621  0.034790  0.092042  0.024257  0.165927
# thalach  -0.149949 -0.001592 -0.123597 -0.013046 -0.041209  0.051405
# exang     0.129027  0.029402  0.089904  0.205900  0.117050 -0.179353
# oldpeak   0.157087  0.097267  0.040155  0.115432  0.002160 -0.099321
# slope     0.100039  0.088087  0.028605  0.091688  0.058552  0.016262
# ca             NaN       NaN       NaN       NaN       NaN       NaN
# thal      0.084672 -0.078866  0.055794  0.082839 -0.071654  0.026280
# ...

# %%
plt.figure(figsize=(15,10))
plt.title('scatter plot')
plt.xlabel('Age')
plt.ylabel('chol')
plt.scatter(df['Age'],df['chol'])
plt.show()

# %%
df.num.value_counts()
# Out:
# 1    56
# 0    51
# 3    42
# 2    41
# 4    10
# Name: num, dtype: int64

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'num' , data = df, palette="Set3" )

# %%
cat_col = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        cat_col.append(x)

# %%
cat_col
# Out:
# []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       200 non-null    int64
#  1   Sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trestbps  200 non-null    float64
#  4   chol      200 non-null    float64
#  5   fbs       200 non-null    float64
#  6   restecg   200 non-null    int64
#  7   thalach   200 non-null    float64
#  8   exang     200 non-null    float64
#  9   oldpeak   200 non-null    float64
#  10  slope     200 non-null    float64
#  11  ca        200 non-null    float64
#  12  thal      200 non-null    float64
#  13  num       200 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 22.0 KB

# %%
x = df.drop('num', axis=1)
y = df['num']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33, random_state=42)

# %%
import sklearn #import many models so that we can compare which model give us good results
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import  DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')


model=[LogisticRegression(), GaussianNB(),SVC(), DecisionTreeClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.2727272727272727
# [[ 4  0  3  3  2]
#  [13  3  3  4  1]
#  [ 6  0  4  2  0]
#  [ 5  1  1  7  0]
#  [ 1  0  1  2  0]]
#               precision    recall  f1-score   support
#
#            0       0.14      0.33      0.20        12
#            1       0.75      0.12      0.21        24
#            2       0.33      0.33      0.33        12
#            3       0.39      0.50      0.44        14
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.27        66
#    macro avg       0.32      0.26      0.24        66
# weighted avg       0.44      0.27      0.27        66
#
#
#
# Accuracy score of GaussianNB() is:
# 0.18181818181818182
# [[1 3 3 3 2]
#  [3 4 5 6 6]
#  [1 4 0 1 6]
#  [0 1 1 4 8]
#  [0 0 0 1 3]]
#               precision    recall  f1-score   support
#
#            0       0.20      0.08      0.12        12
#            1       0.33      0.17      0.22        24
# ...

# %%
import joblib

# %%
joblib.dump(model,"heart_disease")
# Out:
# ['heart_disease']
